# %%
import pandas as pd
from sqlalchemy import create_engine



DATABASE_URL = "postgresql://postgres:123456@localhost:5432/online_retail"
engine = create_engine(DATABASE_URL)

# Função para carregar os dados com cache

def load_data():
    query = "SELECT * FROM view_fonline_stremlit"
    return pd.read_sql(query, engine)

# Carregar os dados
df = load_data()

df
# Out:
#            id  fatura codigo_estoque                             produtos  \
# 0       86816  543600          21533             RETROSPOT LARGE MILK JUG
# 1       86817  543600          22073            RED RETROSPOT STORAGE JAR
# 2       86818  543600          21537           RED RETROSPOT PUDDING BOWL
# 3       86819  543600          21539            RED RETROSPOT BUTTER DISH
# 4       86820  543600          22072    RED RETROSPOT TEA CUP AND SAUCER
# ...       ...     ...            ...                                  ...
# 406824  86811  543598          21464  DISCO BALL ROTATOR BATTERY OPERATED
# 406825  86812  543599         84535B         FAIRY CAKES NOTEBOOK A6 SIZE
# 406826  86813  543600          21531         RED RETROSPOT SUGAR JAM BOWL
# 406827  86814  543600          21527    RED RETROSPOT TRADITIONAL TEAPOT
# 406828  86815  543600          22072    RED RETROSPOT TEA CUP AND SAUCER
#
#         quantidade    data_hora_fatura data_fatura  valor_unitario  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'fatura', 'codigo_estoque', 'produtos', 'quantidade',
#        'data_hora_fatura', 'data_fatura', 'valor_unitario', 'valor_fatura',
#        'id_cliente', 'pais', 'tipo_receita'],
#       dtype='object')

# %%
df = pd.DataFrame(df)
df.groupby('pais')['valor_receita'].sum().sort_values(ascending= False)
# Out:
# pais
# United Kingdom          6767873.394
# Netherlands              284661.540
# EIRE                     250285.220
# Germany                  221698.210
# France                   196712.840
# Australia                137077.270
# Switzerland               55739.400
# Spain                     54774.580
# Belgium                   40910.960
# Sweden                    36595.910
# Japan                     35340.620
# Norway                    35163.460
# Portugal                  29059.810
# Finland                   22326.740
# Channel Islands           20086.290
# Denmark                   18768.140
# Italy                     16890.510
# Cyprus                    12946.290
# Austria                   10154.320
# Singapore                  9120.390
# Poland                     7213.140
# Israel                     6994.250
# Greece                     4710.520
# Iceland                    4310.000
# Canada                     3666.380
# Unspecified                2667.070
# ...

# %%
pip install mplcursors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\HP Victus\anaconda3\Lib\site-packages\pandas-2.2.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\HP Victus\anaconda3\Lib\site-packages\pandas-2.2.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\HP Victus\anaconda3\Lib\site-packages\pandas-2.2.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\HP Victus\anaconda3\Lib\site-packages\pandas-2.2.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\HP Victus\anaconda3\Lib\site-packages\pandas-2.2.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\HP Victus\anaconda3\Lib\site-packages\pandas-2.2.2.dist-info due to invalid metadata entry 'name'
